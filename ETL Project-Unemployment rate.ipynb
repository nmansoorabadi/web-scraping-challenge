# %%
import pandas as pd
from sqlalchemy import create_engine
import json
from pandas.io.json import json_normalize

# %% [markdown]
# ### Store CSV into DataFrame

# %%
# https://www.kaggle.com/jayrav13/unemployment-by-county-us#output.csv
csv_file = "ETL Project/Resources/Unempoyment_rate.csv"
Unempoyment_rate_df = pd.read_csv(csv_file)
Unempoyment_rate_df.head()
# Out:
#    Year     Month        State         County  Rate
# 0  2015  February  Mississippi  Newton County   6.1
# 1  2015  February  Mississippi  Panola County   9.4
# 2  2015  February  Mississippi  Monroe County   7.9
# 3  2015  February  Mississippi   Hinds County   6.1
# 4  2015  February  Mississippi  Kemper County  10.6

# %%
# https://www.kaggle.com/muonneutrino/us-census-demographic-data
### Data for 2015
csv_file = "ETL Project/Resources/acs2015_county_data.csv"
county_data_df = pd.read_csv(csv_file)
county_data_df.head()
# Out:
#    CensusId    State   County  TotalPop    Men  Women  Hispanic  White  Black  \
# 0      1001  Alabama  Autauga     55221  26745  28476       2.6   75.8   18.5
# 1      1003  Alabama  Baldwin    195121  95314  99807       4.5   83.1    9.5
# 2      1005  Alabama  Barbour     26932  14497  12435       4.6   46.2   46.7
# 3      1007  Alabama     Bibb     22604  12073  10531       2.2   74.5   21.4
# 4      1009  Alabama   Blount     57710  28512  29198       8.6   87.9    1.5
#
#    Native  ...  Walk  OtherTransp  WorkAtHome  MeanCommute  Employed  \
# 0     0.4  ...   0.5          1.3         1.8         26.5     23986
# 1     0.6  ...   1.0          1.4         3.9         26.4     85953
# 2     0.2  ...   1.8          1.5         1.6         24.1      8597
# 3     0.4  ...   0.6          1.5         0.7         28.8      8294
# 4     0.3  ...   0.9          0.4         2.3         34.9     22189
#
#    PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# ...

# %%
###Create new data with select columns
county_col=["State","County","TotalPop","Men","Women","Unemployment"]
county_transformed = county_data_df[county_col].copy()

# Set index
county_transformed.set_index("State", inplace=True)

county_transformed.head()
# Out:
#           County  TotalPop    Men  Women  Unemployment
# State
# Alabama  Autauga     55221  26745  28476           7.6
# Alabama  Baldwin    195121  95314  99807           7.5
# Alabama  Barbour     26932  14497  12435          17.6
# Alabama     Bibb     22604  12073  10531           8.3
# Alabama   Blount     57710  28512  29198           7.7

# %%
csv_file = "ETL Project/Resources/acs2015_census_tract_data.csv"
tract_data_df = pd.read_csv(csv_file)
tract_data_df.head()
# Out:
#    CensusTract    State   County  TotalPop   Men  Women  Hispanic  White  \
# 0   1001020100  Alabama  Autauga      1948   940   1008       0.9   87.4
# 1   1001020200  Alabama  Autauga      2156  1059   1097       0.8   40.4
# 2   1001020300  Alabama  Autauga      2968  1364   1604       0.0   74.5
# 3   1001020400  Alabama  Autauga      4423  2172   2251      10.5   82.8
# 4   1001020500  Alabama  Autauga     10763  4922   5841       0.7   68.5
#
#    Black  Native  ...  Walk  OtherTransp  WorkAtHome  MeanCommute  Employed  \
# 0    7.7     0.3  ...   0.5          2.3         2.1         25.0       943
# 1   53.3     0.0  ...   0.0          0.7         0.0         23.4       753
# 2   18.6     0.5  ...   0.0          0.0         2.5         19.6      1373
# 3    3.7     1.6  ...   0.0          2.6         1.6         25.3      1782
# 4   24.8     0.0  ...   0.0          0.6         0.9         24.8      5037
#
#    PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# ...

# %%
###Create new data with select columns
tract_col=["State","County","TotalPop","Men","Women","Unemployment"]
tract__transformed = tract_data_df[tract_col].copy()

# Set index
tract__transformed.set_index("State", inplace=True)

tract__transformed.head()
# Out:
#           County  TotalPop   Men  Women  Unemployment
# State
# Alabama  Autauga      1948   940   1008           5.4
# Alabama  Autauga      2156  1059   1097          13.3
# Alabama  Autauga      2968  1364   1604           6.2
# Alabama  Autauga      4423  2172   2251          10.8
# Alabama  Autauga     10763  4922   5841           4.2

# %%
# https://data.world/garyhoov/unemployment-rate-by-city
# Unemployment rate by city 1990-2016

csv_file = "ETL Project/Resources/Unemployment_rates_by_Metropolitan_Statistical_Area_1990_2016.csv"
Metropolitan_Statistical_df = pd.read_csv(csv_file)
Metropolitan_Statistical_df.head()
# Out:
#                                    Area    Year  Month Civilian Labor Force  \
# 0  Anniston-Oxford-Jacksonville, AL MSA  1990.0    1.0               51,485
# 1                Auburn-Opelika, AL MSA  1990.0    1.0               44,415
# 2             Birmingham-Hoover, AL MSA  1990.0    1.0              457,612
# 3         Daphne-Fairhope-Foley, AL MSA  1990.0    1.0               45,859
# 4                       Decatur, AL MSA  1990.0    1.0               65,452
#
#   Employment Unemployment  Unemployment Rate  State FIPS Code  Area FIPS Code
# 0     48,307        3,178                6.2              1.0         11500.0
# 1     41,247        3,168                7.1              1.0         12220.0
# 2    433,590       24,022                5.2              1.0         13820.0
# 3     43,402        2,457                5.4              1.0         19300.0
# 4     61,009        4,443                6.8              1.0         19460.0

# %%
###Create new data with select columns
Metropolitan_col=["Area","Year","Month","Employment","Unemployment","Unemployment Rate"]
Metropolitan_transformed = Metropolitan_Statistical_df[Metropolitan_col].copy()

# Set index
Metropolitan_transformed.set_index("Area", inplace=True)

Metropolitan_transformed.head()
# Out:
#                                         Year  Month Employment Unemployment  \
# Area
# Anniston-Oxford-Jacksonville, AL MSA  1990.0    1.0     48,307        3,178
# Auburn-Opelika, AL MSA                1990.0    1.0     41,247        3,168
# Birmingham-Hoover, AL MSA             1990.0    1.0    433,590       24,022
# Daphne-Fairhope-Foley, AL MSA         1990.0    1.0     43,402        2,457
# Decatur, AL MSA                       1990.0    1.0     61,009        4,443
#
#                                       Unemployment Rate
# Area
# Anniston-Oxford-Jacksonville, AL MSA                6.2
# Auburn-Opelika, AL MSA                              7.1
# Birmingham-Hoover, AL MSA                           5.2
# Daphne-Fairhope-Foley, AL MSA                       5.4
# Decatur, AL MSA                                     6.8

# %% [markdown]
# ## Store JSON data into a DataFrame

# %%
json_file = "ETL Project/Resources/Unempoyment_yearlry_rate.json"
# print(json_file)

# %%
filepath = json_file
with open(filepath) as jsonfile:
    json_norm = json.load(jsonfile)
# print(json_norm)

# %%
json_normalize(json_norm)
# print(json.dumps(json_norm, indent=4))
# json_normed=json_normalize(json_norm,)
# Out:
#    1990.Annual.Alabama.Unemployment Rate.Autauga County  \
# 0                                                6.5
#
#    1990.Annual.Alabama.Unemployment Rate.Baldwin County  \
# 0                                                5.2
#
#    1990.Annual.Alabama.Unemployment Rate.Barbour County  \
# 0                                                7.8
#
#    1990.Annual.Alabama.Unemployment Rate.Bibb County  \
# 0                                                9.1
#
#    1990.Annual.Alabama.Unemployment Rate.Blount County  \
# 0                                                6.3
#
#    1990.Annual.Alabama.Unemployment Rate.Bullock County  \
# 0                                               12.4
#
#    1990.Annual.Alabama.Unemployment Rate.Butler County  \
# 0                                               12.8
#
#    1990.Annual.Alabama.Unemployment Rate.Calhoun County  \
# 0                                                7.1
#
# ...

# %% [markdown]
# ### Create new data with select columns

# %% [markdown]
# ### Clean DataFrame

# %% [markdown]
# ### Connect to local database

# %% [markdown]
# ### Check for tables

# %% [markdown]
# ### Use pandas to load csv converted DataFrame into database

# %% [markdown]
# ### Use pandas to load json converted DataFrame into database
